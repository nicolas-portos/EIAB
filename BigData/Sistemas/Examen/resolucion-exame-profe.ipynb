# %%
import requests
import pandas as pd

def busca_residente(resident_url):
    resident = requests.get(resident_url).json()
    return resident['name'] + "," + resident['species']

URL="https://rickandmortyapi.com/api/location"

ARCHIVO='archives/locations.csv'
fichero = open(ARCHIVO, 'w')
fichero.write('ID,Planeta,Tipo,Dimensión,Residente,Especie\n')
while(URL != None):
    locations_quest= requests.get(URL)
    for location in (locations_quest.json()['results']):
        aux_residente=''
        if len(location['residents']) > 0:
            aux_residente=busca_residente(location['residents'][0])
        aux_residente = str(location['id']) + "," + location['name'] + "," + location['type'] + "," + location['dimension'] + "," + aux_residente + '\n'
        fichero.write(aux_residente)
    URL=locations_quest.json()['info']['next']
    print("-------------------------------------")
    print(URL)
    print("-------------------------------------")

fichero.close()
# Out:
# -------------------------------------
# https://rickandmortyapi.com/api/location?page=2
# -------------------------------------
# -------------------------------------
# https://rickandmortyapi.com/api/location?page=3
# -------------------------------------
# -------------------------------------
# https://rickandmortyapi.com/api/location?page=4
# -------------------------------------
# -------------------------------------
# https://rickandmortyapi.com/api/location?page=5
# -------------------------------------
# -------------------------------------
# https://rickandmortyapi.com/api/location?page=6
# -------------------------------------
# -------------------------------------
# https://rickandmortyapi.com/api/location?page=7
# -------------------------------------
# -------------------------------------
# None
# -------------------------------------

# %%
df = pd.read_csv(ARCHIVO)
# df.to_json('locations.json')
# df.to_parquet('locations.parquet')
# df.to_csv('locations2.csv')

# %%
df
# Out:
#       ID                    Planeta           Tipo              Dimensión  \
# 0      1              Earth (C-137)         Planet        Dimension C-137
# 1      2                   Abadango        Cluster                unknown
# 2      3           Citadel of Ricks  Space station                unknown
# 3      4          Worldender's lair         Planet                unknown
# 4      5               Anatomy Park     Microverse        Dimension C-137
# ..   ...                        ...            ...                    ...
# 121  122               Avian Planet         Planet  Replacement Dimension
# 122  123  Normal Size Bug Dimension      Dimension                    NaN
# 123  124                 Slartivart         Planet  Replacement Dimension
# 124  125  Rick and Two Crows Planet         Planet  Replacement Dimension
# 125  126            Rick's Memories         Memory                    NaN
#
#                      Residente Especie
# 0                   Beth Smith   Human
# 1    Abadango Cluster Princess   Alien
# 2             Adjudicator Rick   Human
# 3                   Alan Rails   Human
# 4                    Alexander   Human
# ..                         ...     ...
# 121                 Alien Crow   Alien
# 122                    Palicki   Alien
# 123              Slartivartian   Alien
# 124                   Pussifer  Animal
# 125                  Punk Rick   Human
#
# [126 rows x 6 columns]

# %%
df[df['Tipo'] == 'Planet']
# Out:
#       ID                    Planeta    Tipo                   Dimensión  \
# 0      1              Earth (C-137)  Planet             Dimension C-137
# 3      4          Worldender's lair  Planet                     unknown
# 7      8     Post-Apocalyptic Earth  Planet  Post-Apocalyptic Dimension
# 8      9               Purge Planet  Planet       Replacement Dimension
# 9     10               Venzenulon 7  Planet                     unknown
# ..   ...                        ...     ...                         ...
# 111  112                   Morglutz  Planet       Replacement Dimension
# 112  113                   Ferkus 9  Planet       Replacement Dimension
# 121  122               Avian Planet  Planet       Replacement Dimension
# 123  124                 Slartivart  Planet       Replacement Dimension
# 124  125  Rick and Two Crows Planet  Planet       Replacement Dimension
#
#          Residente  Especie
# 0       Beth Smith    Human
# 3       Alan Rails    Human
# 7          Armothy  unknown
# 8        Arthricia    Alien
# 9            Beebo    Alien
# ..             ...      ...
# 111    Morglutzian    Alien
# 112         Daphne    Alien
# 121     Alien Crow    Alien
# 123  Slartivartian    Alien
# 124       Pussifer   Animal
#
# [62 rows x 6 columns]

# %%
df.groupby(['Dimensión']).size()
# Out:
# Dimensión
# Chair Dimension                        1
# Cromulon Dimension                     1
# Cronenberg Dimension                   1
# Dimension 5-126                        1
# Dimension C-137                        5
# Dimension C-35                         1
# Dimension C-500A                       1
# Dimension D-99                         1
# Dimension D716                         1
# Dimension D716-B                       1
# Dimension D716-C                       1
# Dimension J-22                         1
# Dimension J19ζ7                        1
# Dimension K-22                         1
# Dimension K-83                         1
# Eric Stoltz Mask Dimension             1
# Evil Rick's Target Dimension           1
# Fantasy Dimension                      3
# Fascist Dimension                      1
# Fascist Shrimp Dimension               1
# Fascist Teddy Bear Dimension           1
# Giant Telepathic Spiders Dimension     1
# Magic Dimension                        1
# Merged Dimension                       1
# Phone Dimension                        1
# Pizza Dimension                        1
# Post-Apocalyptic Dimension             1
# Replacement Dimension                 57
# Testicle Monster Dimension             1
# Tusk Dimension                         1
# Unknown dimension                      2
# Wasp Dimension                         1
# unknown                               29
# dtype: int64

# %%
df[df['ID']<100]
# Out:
#     ID                                    Planeta  \
# 0    1                              Earth (C-137)
# 1    2                                   Abadango
# 2    3                           Citadel of Ricks
# 3    4                          Worldender's lair
# 4    5                               Anatomy Park
# ..  ..                                        ...
# 94  95  New Improved Galactic Federation Quarters
# 95  96                                Story Train
# 96  97           Non-Diegetic Alternative Reality
# 97  98               Tickets Please Guy Nightmare
# 98  99                              Morty’s Story
#
#                                 Tipo              Dimensión  \
# 0                             Planet        Dimension C-137
# 1                            Cluster                unknown
# 2                      Space station                unknown
# 3                             Planet                unknown
# 4                         Microverse        Dimension C-137
# ..                               ...                    ...
# 94                     Space station  Replacement Dimension
# 95                          Diegesis  Replacement Dimension
# 96  Non-Diegetic Alternative Reality  Replacement Dimension
# 97                         Nightmare  Replacement Dimension
# 98                          Diegesis  Replacement Dimension
#
#                     Residente Especie
# 0                  Beth Smith   Human
# 1   Abadango Cluster Princess   Alien
# 2            Adjudicator Rick   Human
# 3                  Alan Rails   Human
# 4                   Alexander   Human
# ..                        ...     ...
# 94                        NaN     NaN
# 95           Abradolf Lincler   Human
# 96         Tickets Please Guy   Human
# 97          Floaty Bloody Man   Human
# 98                Cookies Guy   Human
#
# [99 rows x 6 columns]

# %%
df[df['Planeta'].str.startswith('Earth')]
# Out:
#     ID                                     Planeta    Tipo  \
# 0    1                               Earth (C-137)  Planet
# 16  17                               Earth (5-126)  Planet
# 19  20               Earth (Replacement Dimension)  Planet
# 22  23                              Earth (C-500A)  Planet
# 25  26                                Earth (K-83)  Planet
# 29  30                   Earth (Unknown dimension)  Planet
# 30  31                               Earth (J19ζ7)  Planet
# 33  34        Earth (Evil Rick's Target Dimension)  Planet
# 41  42  Earth (Giant Telepathic Spiders Dimension)  Planet
# 51  52                                Earth (K-22)  Planet
# 57  58                                Earth (D-99)  Planet
# 58  59                                Earth (D716)  Planet
# 59  60                              Earth (D716-B)  Planet
# 60  61                              Earth (D716-C)  Planet
# 61  62                                Earth (J-22)  Planet
# 68  69                                Earth (C-35)  Planet
# 70  71                     Earth (Pizza Dimension)  Planet
# 71  72                     Earth (Phone Dimension)  Planet
# 73  74                     Earth (Chair Dimension)  Planet
# 76  77                   Earth (Fascist Dimension)  Planet
# 79  80            Earth (Fascist Shrimp Dimension)  Planet
# 80  81        Earth (Fascist Teddy Bear Dimension)  Planet
# 81  82                      Earth (Wasp Dimension)  Planet
# 91  92                      Earth (Tusk Dimension)  Planet
#
#                              Dimensión                   Residente   Especie
# 0                      Dimension C-137                  Beth Smith     Human
# 16                     Dimension 5-126                         NaN       NaN
# 19               Replacement Dimension                Summer Smith     Human
# 22                    Dimension C-500A                Beth Sanchez     Human
# 25                      Dimension K-83                         NaN       NaN
# 29                             unknown                 Young Jerry     Human
# 30                     Dimension J19ζ7                         NaN       NaN
# 33        Evil Rick's Target Dimension                  Beth Smith     Human
# 41  Giant Telepathic Spiders Dimension                      Hunter     Human
# 51                      Dimension K-22                         NaN       NaN
# 57                      Dimension D-99                         NaN       NaN
# 58                      Dimension D716                         NaN       NaN
# 59                    Dimension D716-B                         NaN       NaN
# 60                    Dimension D716-C                         NaN       NaN
# 61                      Dimension J-22                         NaN       NaN
# 68                      Dimension C-35                         NaN       NaN
# 70                     Pizza Dimension                Pizza-person  Humanoid
# 71                     Phone Dimension             Michael Jackson  Humanoid
# 73                     Chair Dimension                Chair-person  Humanoid
# 76                   Fascist Dimension                Mr. Meeseeks  Humanoid
# 79            Fascist Shrimp Dimension         Fascist Shrimp Rick    Animal
# 80        Fascist Teddy Bear Dimension     Fascist Teddy Bear Rick    Animal
# 81                      Wasp Dimension  Caterpillar Mr. Goldenfold    Animal
# 91                      Tusk Dimension                         NaN       NaN
