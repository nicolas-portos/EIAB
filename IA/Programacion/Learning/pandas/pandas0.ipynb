# %%
import pandas as pd
import numpy as np

# %%
filename = "../Archivos/canarias.csv"
df = pd.read_csv(filename, delimiter="\t", decimal=",")
df
# Out:
#                 Isla                     Capital     Área  Población
# 0          El Hierro                    Valverde   268.71      11147
# 1  Fuerteventuranota          Puerto del Rosario  1665.74     119732
# 2       Gran Canaria  Las Palmas de Gran Canaria  1560.10     855521
# 3          La Gomera  San Sebastián de La Gomera   369.76      21678
# 4      Lanzarotenota                    Arrecife   888.07     155812
# 5           La Palma      Santa Cruz de La Palma   708.32      83458
# 6           Tenerife      Santa Cruz de Tenerife  2034.38     928604

# %%
dfl = pd.read_html("https://es.wikipedia.org/wiki/Canarias")
df = dfl[9]
print(df.columns)
df = df.drop(["Bandera", "Escudo"], axis=1)
df.columns = ['Isla', 'Municipios',   'Capital', 'Área', 'Población']

df["Área"] = df["Área"].str.replace(",", ".").str.extract(r'(^[.0-9]+)').astype(float)
df

#df['Población'] = df['Población'].str.extract(r'([0-9]+)')

s1 = df['Población']
print(s1.iloc[0])
print(ord(s1.iloc[0][2]))
c = s1.iloc[0][2]
df['Población'] = df['Población'].str.replace(c, "")
df['Población'] = df['Población'].str.extract(r'([0-9]+)').astype(float)
df["Isla"] = df["Isla"].str.extract(r'([^\[]*)')
df["Provincia"] = ["SCTF", "LPGC", "LPGC", "SCTF", "LPGC", "SCTF", "SCTF"]
df
#df.columns = ["Isla", "n1", "n2", "Municipios", "Capital", "Área", "Población"]
#df.drop(["Bandera", "Escudo"])
# Out:
# Index(['Isla (excepto La Graciosa)', 'Bandera', 'Escudo', 'Municipios',
#        'Capital', 'Área (km²)', 'Población (2022)[18]​'],
#       dtype='object')
# 11 423
# 160
#             Isla  Municipios                     Capital       Área  \
# 0      El Hierro           3                    Valverde   26871.00
# 1  Fuerteventura           6          Puerto del Rosario    1665.74
# 2   Gran Canaria          21  Las Palmas de Gran Canaria  156010.00
# 3      La Gomera           6  San Sebastián de La Gomera   36976.00
# 4      Lanzarote           7                    Arrecife     888.07
# 5       La Palma          14      Santa Cruz de La Palma   70832.00
# 6       Tenerife          31      Santa Cruz de Tenerife  203438.00
#
#    Población Provincia
# 0    11423.0      SCTF
# 1   120021.0      LPGC
# 2   853262.0      LPGC
# 3    21798.0      SCTF
# 4   156112.0      LPGC
# 5    83439.0      SCTF
# 6   931646.0      SCTF

# %%
df["Isla"]
# Out:
# 0        El Hierro
# 1    Fuerteventura
# 2     Gran Canaria
# 3        La Gomera
# 4        Lanzarote
# 5         La Palma
# 6         Tenerife
# Name: Isla, dtype: object

# %%
df = df.reset_index(drop=True)
df = df.set_index("Isla")
df.loc["Gran Canaria":"La Palma", "Capital":"Población"]
# Out:
#                                  Capital       Área  Población
# Isla
# Gran Canaria  Las Palmas de Gran Canaria  156010.00   853262.0
# La Gomera     San Sebastián de La Gomera   36976.00    21798.0
# Lanzarote                       Arrecife     888.07   156112.0
# La Palma          Santa Cruz de La Palma   70832.00    83439.0

# %%
df.iloc[0:3, 0:2]
# Out:
#                Municipios                     Capital
# Isla
# El Hierro               3                    Valverde
# Fuerteventura           6          Puerto del Rosario
# Gran Canaria           21  Las Palmas de Gran Canaria

# %%
df = df.reset_index()
df
# Out:
#             Isla  Municipios                     Capital       Área  \
# 0      El Hierro           3                    Valverde   26871.00
# 1  Fuerteventura           6          Puerto del Rosario    1665.74
# 2   Gran Canaria          21  Las Palmas de Gran Canaria  156010.00
# 3      La Gomera           6  San Sebastián de La Gomera   36976.00
# 4      Lanzarote           7                    Arrecife     888.07
# 5       La Palma          14      Santa Cruz de La Palma   70832.00
# 6       Tenerife          31      Santa Cruz de Tenerife  203438.00
#
#    Población Provincia
# 0    11423.0      SCTF
# 1   120021.0      LPGC
# 2   853262.0      LPGC
# 3    21798.0      SCTF
# 4   156112.0      LPGC
# 5    83439.0      SCTF
# 6   931646.0      SCTF

# %%
mascara = df["Municipios"] > 6
mascara
df[mascara]
df[df["Municipios"] > 6]
df.query("Municipios > 6")
# Out:
#            Isla  Municipios                     Capital       Área  Población  \
# 2  Gran Canaria          21  Las Palmas de Gran Canaria  156010.00   853262.0
# 4     Lanzarote           7                    Arrecife     888.07   156112.0
# 5      La Palma          14      Santa Cruz de La Palma   70832.00    83439.0
# 6      Tenerife          31      Santa Cruz de Tenerife  203438.00   931646.0
#
#   Provincia
# 2      LPGC
# 4      LPGC
# 5      SCTF
# 6      SCTF

# %%
mascara = df["Provincia"].isin(["SCTF"])
mascara
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# Name: Provincia, dtype: bool

# %%
df
# Out:
#             Isla  Municipios                     Capital       Área  \
# 0      El Hierro           3                    Valverde   26871.00
# 1  Fuerteventura           6          Puerto del Rosario    1665.74
# 2   Gran Canaria          21  Las Palmas de Gran Canaria  156010.00
# 3      La Gomera           6  San Sebastián de La Gomera   36976.00
# 4      Lanzarote           7                    Arrecife     888.07
# 5       La Palma          14      Santa Cruz de La Palma   70832.00
# 6       Tenerife          31      Santa Cruz de Tenerife  203438.00
#
#    Población Provincia
# 0    11423.0      SCTF
# 1   120021.0      LPGC
# 2   853262.0      LPGC
# 3    21798.0      SCTF
# 4   156112.0      LPGC
# 5    83439.0      SCTF
# 6   931646.0      SCTF

# %%
s = pd.Series(data=["ibiza", 4, "asd", 3, 7 , "????"], index=df.columns, name="pepe")
s
df = pd.concat([df, s.to_frame().T])
df
df = df.drop(index="pepe")
df
# Out:
#             Isla Municipios                     Capital      Área Población  \
# 0      El Hierro          3                    Valverde   26871.0   11423.0
# 1  Fuerteventura          6          Puerto del Rosario   1665.74  120021.0
# 2   Gran Canaria         21  Las Palmas de Gran Canaria  156010.0  853262.0
# 3      La Gomera          6  San Sebastián de La Gomera   36976.0   21798.0
# 4      Lanzarote          7                    Arrecife    888.07  156112.0
# 5       La Palma         14      Santa Cruz de La Palma   70832.0   83439.0
# 6       Tenerife         31      Santa Cruz de Tenerife  203438.0  931646.0
#
#   Provincia
# 0      SCTF
# 1      LPGC
# 2      LPGC
# 3      SCTF
# 4      LPGC
# 5      SCTF
# 6      SCTF

# %%
df["viento"] = [1,2,3,4,5,6,7]
df
df = df.drop(columns="viento")
df
# Out:
#             Isla Municipios                     Capital      Área Población  \
# 0      El Hierro          3                    Valverde   26871.0   11423.0
# 1  Fuerteventura          6          Puerto del Rosario   1665.74  120021.0
# 2   Gran Canaria         21  Las Palmas de Gran Canaria  156010.0  853262.0
# 3      La Gomera          6  San Sebastián de La Gomera   36976.0   21798.0
# 4      Lanzarote          7                    Arrecife    888.07  156112.0
# 5       La Palma         14      Santa Cruz de La Palma   70832.0   83439.0
# 6       Tenerife         31      Santa Cruz de Tenerife  203438.0  931646.0
#
#   Provincia
# 0      SCTF
# 1      LPGC
# 2      LPGC
# 3      SCTF
# 4      LPGC
# 5      SCTF
# 6      SCTF

# %%
import datetime
df["Fvisita"] = ["1/12/2023","13/1/2023","1/12/2022","1/1/2023","12/12/2023","1/12/2020","1/12/2022",]
df
df["Fvisita"]=pd.to_datetime(df["Fvisita"], dayfirst=True)
df
df["year"] = df["Fvisita"].dt.year
df["Fvisita"].dt.month == 1 
df
# Out:
#             Isla Municipios                     Capital      Área Población  \
# 0      El Hierro          3                    Valverde   26871.0   11423.0
# 1  Fuerteventura          6          Puerto del Rosario   1665.74  120021.0
# 2   Gran Canaria         21  Las Palmas de Gran Canaria  156010.0  853262.0
# 3      La Gomera          6  San Sebastián de La Gomera   36976.0   21798.0
# 4      Lanzarote          7                    Arrecife    888.07  156112.0
# 5       La Palma         14      Santa Cruz de La Palma   70832.0   83439.0
# 6       Tenerife         31      Santa Cruz de Tenerife  203438.0  931646.0
#
#   Provincia    Fvisita  year
# 0      SCTF 2023-12-01  2023
# 1      LPGC 2023-01-13  2023
# 2      LPGC 2022-12-01  2022
# 3      SCTF 2023-01-01  2023
# 4      LPGC 2023-12-12  2023
# 5      SCTF 2020-12-01  2020
# 6      SCTF 2022-12-01  2022

# %%
df = df.reset_index(drop=True)
df = df.set_index("Fvisita")
df.loc["2022"]
df.sort_index().loc["2020-01-01":"2022-12-31"]
df = df.reset_index()

# %%
df
# Out:
#      Fvisita           Isla Municipios                     Capital      Área  \
# 0 2023-12-01      El Hierro          3                    Valverde   26871.0
# 1 2023-01-13  Fuerteventura          6          Puerto del Rosario   1665.74
# 2 2022-12-01   Gran Canaria         21  Las Palmas de Gran Canaria  156010.0
# 3 2023-01-01      La Gomera          6  San Sebastián de La Gomera   36976.0
# 4 2023-12-12      Lanzarote          7                    Arrecife    888.07
# 5 2020-12-01       La Palma         14      Santa Cruz de La Palma   70832.0
# 6 2022-12-01       Tenerife         31      Santa Cruz de Tenerife  203438.0
#
#   Población Provincia  year
# 0   11423.0      SCTF  2023
# 1  120021.0      LPGC  2023
# 2  853262.0      LPGC  2022
# 3   21798.0      SCTF  2023
# 4  156112.0      LPGC  2023
# 5   83439.0      SCTF  2020
# 6  931646.0      SCTF  2022

# %%
mask = pd.to_datetime("today").year - df["Fvisita"].dt.year < 2
df.loc[mask, "Vreciente"] = "Hace poco"
mask = ~mask
df.loc[mask, "Vreciente"] = "Hace bastante"
df
# Out:
#      Fvisita           Isla Municipios                     Capital      Área  \
# 0 2023-12-01      El Hierro          3                    Valverde   26871.0
# 1 2023-01-13  Fuerteventura          6          Puerto del Rosario   1665.74
# 2 2022-12-01   Gran Canaria         21  Las Palmas de Gran Canaria  156010.0
# 3 2023-01-01      La Gomera          6  San Sebastián de La Gomera   36976.0
# 4 2023-12-12      Lanzarote          7                    Arrecife    888.07
# 5 2020-12-01       La Palma         14      Santa Cruz de La Palma   70832.0
# 6 2022-12-01       Tenerife         31      Santa Cruz de Tenerife  203438.0
#
#   Población Provincia  year      Vreciente
# 0   11423.0      SCTF  2023      Hace poco
# 1  120021.0      LPGC  2023      Hace poco
# 2  853262.0      LPGC  2022  Hace bastante
# 3   21798.0      SCTF  2023      Hace poco
# 4  156112.0      LPGC  2023      Hace poco
# 5   83439.0      SCTF  2020  Hace bastante
# 6  931646.0      SCTF  2022  Hace bastante

# %%
df = df.drop("Vreciente", axis=1)
mask1 = pd.to_datetime("today").year - df["Fvisita"].dt.year < 2
mask2 = ~mask1
df["Vreciente"] = np.select([mask1, mask2], ["Hace poco", "Hace bastante"])
df
# Out:
#      Fvisita           Isla Municipios                     Capital      Área  \
# 0 2023-12-01      El Hierro          3                    Valverde   26871.0
# 1 2023-01-13  Fuerteventura          6          Puerto del Rosario   1665.74
# 2 2022-12-01   Gran Canaria         21  Las Palmas de Gran Canaria  156010.0
# 3 2023-01-01      La Gomera          6  San Sebastián de La Gomera   36976.0
# 4 2023-12-12      Lanzarote          7                    Arrecife    888.07
# 5 2020-12-01       La Palma         14      Santa Cruz de La Palma   70832.0
# 6 2022-12-01       Tenerife         31      Santa Cruz de Tenerife  203438.0
#
#   Población Provincia  year      Vreciente
# 0   11423.0      SCTF  2023      Hace poco
# 1  120021.0      LPGC  2023      Hace poco
# 2  853262.0      LPGC  2022  Hace bastante
# 3   21798.0      SCTF  2023      Hace poco
# 4  156112.0      LPGC  2023      Hace poco
# 5   83439.0      SCTF  2020  Hace bastante
# 6  931646.0      SCTF  2022  Hace bastante

# %%
from pandas.api.types import CategoricalDtype
df["Vreciente"].astype("category")
visita_cat = CategoricalDtype(categories = ['Nunca', 'Hace bastante', 'Hace poco'], ordered=True)
df["Vreciente"].astype(visita_cat)
df
# Out:
#      Fvisita           Isla Municipios                     Capital      Área  \
# 0 2023-12-01      El Hierro          3                    Valverde   26871.0
# 1 2023-01-13  Fuerteventura          6          Puerto del Rosario   1665.74
# 2 2022-12-01   Gran Canaria         21  Las Palmas de Gran Canaria  156010.0
# 3 2023-01-01      La Gomera          6  San Sebastián de La Gomera   36976.0
# 4 2023-12-12      Lanzarote          7                    Arrecife    888.07
# 5 2020-12-01       La Palma         14      Santa Cruz de La Palma   70832.0
# 6 2022-12-01       Tenerife         31      Santa Cruz de Tenerife  203438.0
#
#   Población Provincia  year      Vreciente
# 0   11423.0      SCTF  2023      Hace poco
# 1  120021.0      LPGC  2023      Hace poco
# 2  853262.0      LPGC  2022  Hace bastante
# 3   21798.0      SCTF  2023      Hace poco
# 4  156112.0      LPGC  2023      Hace poco
# 5   83439.0      SCTF  2020  Hace bastante
# 6  931646.0      SCTF  2022  Hace bastante

# %%
pd.cut(df["Población"], 3)
pd.cut(df["Población"], 3, labels=["Poca", "Media", "Bastante"])
# Out:
# 0        Poca
# 1        Poca
# 2    Bastante
# 3        Poca
# 4        Poca
# 5        Poca
# 6    Bastante
# Name: Población, dtype: category
# Categories (3, object): ['Poca' < 'Media' < 'Bastante']

# %%
df.sort_values(by=["Provincia" , "Población" ])
# Out:
#      Fvisita           Isla Municipios                     Capital      Área  \
# 1 2023-01-13  Fuerteventura          6          Puerto del Rosario   1665.74
# 4 2023-12-12      Lanzarote          7                    Arrecife    888.07
# 2 2022-12-01   Gran Canaria         21  Las Palmas de Gran Canaria  156010.0
# 0 2023-12-01      El Hierro          3                    Valverde   26871.0
# 3 2023-01-01      La Gomera          6  San Sebastián de La Gomera   36976.0
# 5 2020-12-01       La Palma         14      Santa Cruz de La Palma   70832.0
# 6 2022-12-01       Tenerife         31      Santa Cruz de Tenerife  203438.0
#
#   Población Provincia  year      Vreciente
# 1  120021.0      LPGC  2023      Hace poco
# 4  156112.0      LPGC  2023      Hace poco
# 2  853262.0      LPGC  2022  Hace bastante
# 0   11423.0      SCTF  2023      Hace poco
# 3   21798.0      SCTF  2023      Hace poco
# 5   83439.0      SCTF  2020  Hace bastante
# 6  931646.0      SCTF  2022  Hace bastante

# %%
df.set_index("Isla")
df["Población"]=pd.to_numeric(df['Población'])
df["Población"].idxmax()
print(df.loc[df["Población"].idxmax()])
df.reset_index()
# Out:
# Fvisita          2022-12-01 00:00:00
# Isla                        Tenerife
# Municipios                        31
# Capital       Santa Cruz de Tenerife
# Área                        203438.0
# Población                   931646.0
# Provincia                       SCTF
# year                            2022
# Vreciente              Hace bastante
# Name: 6, dtype: object
#    index    Fvisita           Isla Municipios                     Capital  \
# 0      0 2023-12-01      El Hierro          3                    Valverde
# 1      1 2023-01-13  Fuerteventura          6          Puerto del Rosario
# 2      2 2022-12-01   Gran Canaria         21  Las Palmas de Gran Canaria
# 3      3 2023-01-01      La Gomera          6  San Sebastián de La Gomera
# 4      4 2023-12-12      Lanzarote          7                    Arrecife
# 5      5 2020-12-01       La Palma         14      Santa Cruz de La Palma
# 6      6 2022-12-01       Tenerife         31      Santa Cruz de Tenerife
#
#        Área  Población Provincia  year      Vreciente
# 0   26871.0    11423.0      SCTF  2023      Hace poco
# 1   1665.74   120021.0      LPGC  2023      Hace poco
# 2  156010.0   853262.0      LPGC  2022  Hace bastante
# 3   36976.0    21798.0      SCTF  2023      Hace poco
# 4    888.07   156112.0      LPGC  2023      Hace poco
# 5   70832.0    83439.0      SCTF  2020  Hace bastante
# 6  203438.0   931646.0      SCTF  2022  Hace bastante

# %%
df
#df = df.drop(columns=["level_0", "index"])
df
df.reset_index()
df
# Out:
#      Fvisita           Isla Municipios                     Capital      Área  \
# 0 2023-12-01      El Hierro          3                    Valverde   26871.0
# 1 2023-01-13  Fuerteventura          6          Puerto del Rosario   1665.74
# 2 2022-12-01   Gran Canaria         21  Las Palmas de Gran Canaria  156010.0
# 3 2023-01-01      La Gomera          6  San Sebastián de La Gomera   36976.0
# 4 2023-12-12      Lanzarote          7                    Arrecife    888.07
# 5 2020-12-01       La Palma         14      Santa Cruz de La Palma   70832.0
# 6 2022-12-01       Tenerife         31      Santa Cruz de Tenerife  203438.0
#
#    Población Provincia  year      Vreciente
# 0    11423.0      SCTF  2023      Hace poco
# 1   120021.0      LPGC  2023      Hace poco
# 2   853262.0      LPGC  2022  Hace bastante
# 3    21798.0      SCTF  2023      Hace poco
# 4   156112.0      LPGC  2023      Hace poco
# 5    83439.0      SCTF  2020  Hace bastante
# 6   931646.0      SCTF  2022  Hace bastante

# %%
df["Población"].nlargest(3)
df.nlargest(3, "Población")
df.set_index("Isla")

df.reset_index()
# Out:
#    index    Fvisita           Isla Municipios                     Capital  \
# 0      0 2023-12-01      El Hierro          3                    Valverde
# 1      1 2023-01-13  Fuerteventura          6          Puerto del Rosario
# 2      2 2022-12-01   Gran Canaria         21  Las Palmas de Gran Canaria
# 3      3 2023-01-01      La Gomera          6  San Sebastián de La Gomera
# 4      4 2023-12-12      Lanzarote          7                    Arrecife
# 5      5 2020-12-01       La Palma         14      Santa Cruz de La Palma
# 6      6 2022-12-01       Tenerife         31      Santa Cruz de Tenerife
#
#        Área  Población Provincia  year      Vreciente
# 0   26871.0    11423.0      SCTF  2023      Hace poco
# 1   1665.74   120021.0      LPGC  2023      Hace poco
# 2  156010.0   853262.0      LPGC  2022  Hace bastante
# 3   36976.0    21798.0      SCTF  2023      Hace poco
# 4    888.07   156112.0      LPGC  2023      Hace poco
# 5   70832.0    83439.0      SCTF  2020  Hace bastante
# 6  203438.0   931646.0      SCTF  2022  Hace bastante

# %%
# esto es una serie de panda
df["Área"] = pd.to_numeric(df["Área"])
df["Población"] / df["Área"]
(df["Población"] / df["Área"]).nlargest(3).index
df.iloc[(df["Población"] / df["Área"]).nlargest(3).index]

#también valdría
idx = (df["Población"] / df["Área"]).sort_values(ascending=False).index
df.iloc[idx[:3]]
# Out:
#      Fvisita           Isla Municipios                     Capital       Área  \
# 4 2023-12-12      Lanzarote          7                    Arrecife     888.07
# 1 2023-01-13  Fuerteventura          6          Puerto del Rosario    1665.74
# 2 2022-12-01   Gran Canaria         21  Las Palmas de Gran Canaria  156010.00
#
#    Población Provincia  year      Vreciente
# 4   156112.0      LPGC  2023      Hace poco
# 1   120021.0      LPGC  2023      Hace poco
# 2   853262.0      LPGC  2022  Hace bastante

# %%
data = [[1, 2,10], [3, np.nan, 11], [5, 6, 12]]
df = pd.DataFrame(data, columns=[ "A" , "B", "C" ])
print(df)
# Out:
#    A    B   C
# 0  1  2.0  10
# 1  3  NaN  11
# 2  5  6.0  12

# %%
df.isna()
df.dropna()
df.dropna(axis = 1)
df.fillna(1000)
df.interpolate(axis = 1)
df.interpolate()
df.index = [100,102,101]

# %%
df.sort_index()
# Out:
#      A    B   C
# 100  1  2.0  10
# 101  5  6.0  12
# 102  3  NaN  11

# %%
df.sort_index().interpolate()
# Out:
#      A    B   C
# 100  1  2.0  10
# 101  5  6.0  12
# 102  3  6.0  11

# %%
df
# Out:
#      A    B   C
# 100  1  2.0  10
# 102  3  NaN  11
# 101  5  6.0  12
