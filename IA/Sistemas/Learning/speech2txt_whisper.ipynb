# %%
# %pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to c:\users\nicol\appdata\local\temp\pip-req-build-hvxtxc2e
#   Resolved https://github.com/openai/whisper.git to commit 279133e3107392276dc509148da1f41bfb532c7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numba in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from openai-whisper==20231117) (0.60.0)
# Requirement already satisfied: numpy in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from openai-whisper==20231117) (1.22.0)
# Requirement already satisfied: torch in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from openai-whisper==20231117) (2.4.1)
# Requirement already satisfied: tqdm in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from openai-whisper==20231117) (4.66.5)
# Requirement already satisfied: more-itertools in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from openai-whisper==20231117) (10.5.0)
# Requirement already satisfied: tiktoken in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from openai-whisper==20231117) (0.7.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from numba->openai-whisper==20231117) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from tiktoken->openai-whisper==20231117) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in c:\users\nicol\appdata\roaming\python\python310\site-packages (from tiktoken->openai-whisper==20231117) (2.32.3)
# Requirement already satisfied: filelock in c:\users\nicol\appdata\roaming\python\python310\site-packages (from torch->openai-whisper==20231117) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from torch->openai-whisper==20231117) (4.11.0)
# Requirement already satisfied: sympy in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from torch->openai-whisper==20231117) (1.13.2)
# Requirement already satisfied: networkx in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from torch->openai-whisper==20231117) (2.8.8)
# Requirement already satisfied: jinja2 in c:\users\nicol\appdata\roaming\python\python310\site-packages (from torch->openai-whisper==20231117) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\nicol\appdata\roaming\python\python310\site-packages (from torch->openai-whisper==20231117) (2024.6.1)
# Requirement already satisfied: colorama in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from tqdm->openai-whisper==20231117) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nicol\appdata\roaming\python\python310\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nicol\appdata\roaming\python\python310\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nicol\appdata\roaming\python\python310\site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nicol\appdata\roaming\python\python310\site-packages (from jinja2->torch->openai-whisper==20231117) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nicol\miniconda3\envs\ia\lib\site-packages (from sympy->torch->openai-whisper==20231117) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git 'C:\Users\nicol\AppData\Local\Temp\pip-req-build-hvxtxc2e'

# %%
# !conda install -y -c conda-forge ffmpeg

# %%
import pandas as pd
import os
import whisper
from whisper.utils import WriteTXT, WriteSRT, WriteVTT

# %%
model = whisper.load_model("small")

# %%
result = model.transcribe("archives/harvard.wav")

# %%
result
# Out:
# {'text': ' The stale smell of old beer lingers. It takes heat to bring out the odor. A cold dip restores health and zest. A salt pickle tastes fine with ham. Tacos al pastor are my favorite. A zestful food is the hot cross bun.',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 4.0,
#    'text': ' The stale smell of old beer lingers.',
#    'tokens': [50364,
#     440,
#     342,
#     1220,
#     4316,
#     295,
#     1331,
#     8795,
#     22949,
#     433,
#     13,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.1360245035655463,
#    'compression_ratio': 1.4210526315789473,
#    'no_speech_prob': 0.04962493106722832},
#   {'id': 1,
#    'seek': 0,
#    'start': 4.0,
#    'end': 7.0,
#    'text': ' It takes heat to bring out the odor.',
#    'tokens': [50564, 467, 2516, 3738, 281, 1565, 484, 264, 41176, 13, 50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.1360245035655463,
#    'compression_ratio': 1.4210526315789473,
#    'no_speech_prob': 0.04962493106722832},
#   {'id': 2,
#    'seek': 0,
#    'start': 7.0,
#    'end': 10.0,
#    'text': ' A cold dip restores health and zest.',
#    'tokens': [50714,
#     316,
#     3554,
#     10460,
#     1472,
#     2706,
#     1585,
#     293,
#     37889,
#     13,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.1360245035655463,
#    'compression_ratio': 1.4210526315789473,
#    'no_speech_prob': 0.04962493106722832},
#   {'id': 3,
#    'seek': 0,
#    'start': 10.0,
#    'end': 12.0,
#    'text': ' A salt pickle tastes fine with ham.',
#    'tokens': [50864, 316, 5139, 31433, 8666, 2489, 365, 7852, 13, 50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.1360245035655463,
#    'compression_ratio': 1.4210526315789473,
#    'no_speech_prob': 0.04962493106722832},
#   {'id': 4,
#    'seek': 0,
#    'start': 12.0,
#    'end': 15.0,
#    'text': ' Tacos al pastor are my favorite.',
#    'tokens': [50964, 38848, 329, 419, 21193, 366, 452, 2954, 13, 51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.1360245035655463,
#    'compression_ratio': 1.4210526315789473,
#    'no_speech_prob': 0.04962493106722832},
#   {'id': 5,
#    'seek': 0,
#    'start': 15.0,
#    'end': 18.0,
#    'text': ' A zestful food is the hot cross bun.',
#    'tokens': [51114,
#     316,
#     37889,
#     906,
#     1755,
#     307,
#     264,
#     2368,
#     3278,
#     6702,
#     13,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.1360245035655463,
#    'compression_ratio': 1.4210526315789473,
#    'no_speech_prob': 0.04962493106722832}],
#  'language': 'en'}

# %%
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Crear instancias de las clases para escribir los resultados
write_txt = WriteTXT(output_dir)
write_srt = WriteSRT(output_dir)
write_vtt = WriteVTT(output_dir)

# Escribir la transcripción en un archivo TXT
write_txt(result, "test")
# Escribir los subtítulos en archivos SRT y VTT
write_srt(result, "test")
write_vtt(result, "test")

# %%
# a más bajo nivel, pasando el contenido de audio
import whisper

model = whisper.load_model("small")

# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("archives/harvard.wav")
audio = whisper.pad_or_trim(audio)

# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")

# decode the audio
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# print the recognized text
print(result.text)
# Out:
# Detected language: en
# The stale smell of old beer lingers. It takes heat to bring out the odor. A cold dip restores health and zest. A salt pickle tastes fine with ham. Tacos al pastor are my favorite. A zestful food is the hot cross bun.
